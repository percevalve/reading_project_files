# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from openpyxl import load_workbook

# %% [markdown]
# # Loading the data
#
# Latin1 or iso-8859-1 encoding seem to be not giving any error. Also tested :
# - UTF-8 : codec can't decode byte 0xa3 in position 55: invalid start byte
# - UTF-16 : stream does not start with BOM

# %%
with open("pm_hack/OneDrive_1_05-10-2018/Headers.csv", 'rt') as f:
    headers = pd.read_csv(f)

# %%
data = dict()
for file in range(2013,2019):
    print(file)
    with open("pm_hack/OneDrive_1_05-10-2018/%s.csv"%file, 'rt') as f:
        data[file] = pd.read_csv(f,header=None)
        data[file].columns = headers.columns
        data["year"] = file
# Out:
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018

# %%
all_data = pd.concat([item for _,item in data.items()])

# %%
for col in ['userid','company','company_de']:
    all_data[col] = pd.to_numeric(all_data[col],downcast='unsigned')

# %%
wb = load_workbook(filename='pm_hack/OneDrive_1_05-10-2018/SRM Trades.xlsx', read_only=True)
ws = wb.active
srm = list()
for row in ws.rows:
    srm_list = {'id': row[0].value ,'trade': row[1].value , 'active': row[2].value}
    srm.append(srm_list)
srm_df = pd.DataFrame.from_records(srm[1:]) #first line is the header

# %%
test_df.rename({"trade":"trade_test"},axis=1)
# Out:
#            userid                  swipeIn                 swipeOut  auto  \
# 1185711   83115.0  2018-09-08 12:04:16.000  2018-09-08 12:09:43.000     0
# 2297401   19385.0  2017-08-21 13:47:43.000  2017-08-21 13:49:24.000     0
# 1413780    9306.0  2014-08-26 14:47:20.000  2014-08-26 18:33:58.000     0
# 2867187  116301.0  2017-10-18 07:32:13.000  2017-10-18 16:32:23.000     0
# 26331    121085.0  2018-01-08 12:59:36.000  2018-01-08 18:03:06.000     0
# 2136186   73257.0  2016-05-28 10:05:55.000  2016-05-28 11:31:23.000     0
# 764125    21417.0  2014-06-04 14:25:57.000  2014-06-04 14:28:23.000     0
# 3223537   74578.0  2016-08-04 06:59:24.000  2016-08-04 06:59:54.000     0
# 2216038   73586.0  2016-06-03 16:21:49.000  2016-06-03 16:22:14.000     0
# 3734453   64681.0  2015-11-11 10:27:48.000  2015-11-11 12:58:17.000     0
# 3065461  107314.0  2017-11-10 07:16:40.000  2017-11-10 07:32:08.000     0
# 1238484   19028.0  2016-04-15 08:18:37.000  2016-04-15 08:18:37.000     1
# 614025   124299.0  2018-04-06 06:50:25.000  2018-04-06 14:51:27.000     0
# 278058    57069.0  2016-01-26 12:50:39.000  2016-01-26 12:52:10.000     0
# 456564    59200.0  2016-02-10 07:27:24.000  2016-02-10 16:50:40.000     0
# 1338149   80951.0  2017-05-18 13:55:43.000  2017-05-18 13:59:52.000     0
# 3776656   88112.0  2016-09-10 13:26:43.000  2016-09-10 14:56:21.000     0
# 4233163   47681.0  2016-10-17 11:49:26.000  2016-10-17 12:34:05.000     0
# 2765600  112178.0  2017-10-05 17:07:50.000  2017-10-05 17:07:50.000     1
# 664312    15782.0  2014-05-20 17:56:53.000  2014-05-20 18:05:44.000     0
# 2338837   35173.0  2016-06-13 07:33:25.000  2016-06-13 11:53:06.000     0
# 380089    15577.0  2014-03-31 08:02:05.000  2014-03-31 08:58:56.000     0
# 1298379   40400.0  2015-05-02 10:30:52.000  2015-05-02 10:31:49.000     0
# 3730785   30108.0  2015-11-11 07:38:38.000  2015-11-11 08:53:16.000     0
# 3600494   64661.0  2016-08-27 16:30:52.000  2016-08-27 16:31:12.000     0
# 4660385   83516.0  2016-11-18 13:55:58.000  2016-11-18 14:43:00.000     0
# 2157298  106369.0  2017-08-08 06:57:51.000  2017-08-08 09:55:49.000     0
# 976798    63699.0  2016-03-23 10:10:20.000  2016-03-23 10:10:20.000     1
# 2462532   43188.0  2015-07-25 10:33:26.000  2015-07-25 11:36:54.000     0
# 3772623   71493.0  2016-09-09 14:19:59.000  2016-09-09 14:50:25.000     0
# 1187193    6619.0  2014-07-28 13:04:06.000  2014-07-28 16:27:02.000     0
# 148186    89426.0  2018-01-26 08:16:46.000  2018-01-26 10:33:53.000     0
# 100642    37718.0  2015-01-15 11:27:30.000  2015-01-15 11:28:32.000     0
# 4321080   89074.0  2016-10-24 11:40:56.000  2016-10-24 11:40:56.000     1
# 59133     71305.0  2017-01-11 08:07:52.000  2017-01-11 08:08:22.000     0
# 208569     6670.0  2014-03-03 13:33:55.000  2014-03-03 17:56:17.000     0
# 3044403   63460.0  2015-09-10 15:06:48.000  2015-09-10 16:44:17.000     0
# 4225207   64740.0  2016-10-17 02:00:08.000  2016-10-17 02:33:28.000     0
# 2549919   53605.0  2015-07-31 08:53:16.000  2015-07-31 08:53:31.000     0
# 642905   122485.0  2018-04-11 08:28:05.000  2018-04-11 10:10:43.000     0
# 3089965   67229.0  2016-07-27 08:22:00.000  2016-07-27 08:36:11.000     0
# 1048450   96131.0  2017-04-20 16:30:49.000  2017-04-20 16:30:49.000     1
# 503764    18531.0  2014-04-23 13:12:57.000  2014-04-23 15:50:32.000     0
# 3902643   27835.0  2015-11-25 15:26:41.000  2015-11-25 15:26:41.000     1
# 932674    19372.0  2015-04-01 11:33:36.000  2015-04-01 11:34:56.000     0
# 3702839   55490.0  2015-11-09 10:00:01.000  2015-11-09 10:00:01.000     1
# 2240919   36526.0  2014-12-05 12:10:55.000  2014-12-05 15:30:05.000     0
# 2596342   67008.0  2017-09-19 19:04:54.000  2017-09-20 06:53:24.000     0
# 2881818   30234.0  2015-08-26 13:39:16.000  2015-08-26 17:09:31.000     0
# 3213513   73789.0  2016-08-03 08:53:32.000  2016-08-03 08:53:32.000     1
#
#          company  company_de  trade_test  panel_in  panel_out  AreaID  SiteID  \
# 1185711    125.0       125.0      1432.0       465        466     110      75
# 2297401    200.0       200.0      1891.0       416        418     116      81
# 1413780     11.0        11.0      1233.0        94         95      26      23
# 2867187   3862.0      3862.0      2078.0       360        359     102      71
# 26331     3604.0      3604.0      1250.0       351        352     103      24
# 2136186    938.0       938.0      1202.0       237        237      76      37
# 764125     492.0       492.0      1274.0        74         73      17      15
# 3223537    188.0       188.0      1501.0       287        289      71      49
# 2216038     90.0        90.0      2044.0       218        219      49      35
# 3734453    904.0       904.0      1201.0        73         72      18      15
# 3065461    134.0      3611.0      1229.0       454        458     126      85
# 1238484    200.0       200.0      1891.0       280          0      86      57
# 614025    3604.0      3604.0      1250.0       351        352     103      24
# 278058     863.0       863.0      1265.0       234        199      53      37
# 456564    1195.0      1195.0      1202.0        29         16       5       3
# 1338149   1873.0      1873.0      1300.0       301        302      89      41
# 3776656   3182.0      3182.0      1229.0       321        324      47      34
# 4233163   1384.0      1384.0      1956.0       378        294      68      42
# 2765600     12.0        12.0      1285.0       461          0     128      41
# 664312     492.0       492.0      1229.0        74         68      17      15
# 2338837     52.0        52.0      1271.0       172        185      53      37
# 380089     492.0       492.0      1229.0        73         72      18      15
# 1298379   1241.0      1241.0      1201.0        63         61      15      12
# 3730785     95.0        95.0      1457.0        15         16       5       3
# 3600494    216.0       216.0      1265.0        72         70      17      15
# 4660385    709.0       709.0      1733.0       294        293      67      42
# 2157298   1662.0      1662.0      1393.0       380        381      68      42
# 976798    1080.0      1080.0      1533.0       323          0      47      34
# 2462532     52.0        52.0      1233.0       233        199      53      37
# 3772623    870.0       870.0      1250.0       162        163      49      35
# 1187193    124.0       124.0      1202.0       108        109      32      25
# 148186       2.0         2.0      1447.0       461        462     128      41
# 100642     986.0       986.0      1281.0        65         62      15      12
# 4321080   3329.0      3329.0      1229.0       224          0      72      49
# 59133       90.0        90.0      1375.0       218        219      49      35
# 208569      82.0        82.0      1233.0        27         28       9       6
# 3044403   1250.0      1250.0      1194.0        95         97      27      23
# 4225207     95.0        95.0      1447.0       184        173      53      37
# 2549919    183.0       183.0      2545.0        60         62      15      12
# 642905     760.0       760.0      1727.0       465        466     110      75
# 3089965    188.0       188.0      1432.0       291        225      72      49
# 1048450   1873.0      1873.0      1202.0       303          0      90      41
# 503764     231.0       231.0      1393.0        80         79      20      16
# 3902643     95.0        95.0      1193.0       237          0      76      37
# 932674     623.0       623.0      1233.0        88         89      24      18
# 3702839    354.0         2.0      1145.0       224          0      72      49
# 2240919    847.0       847.0      2032.0       164        165      50      36
# 2596342    835.0       835.0      1285.0       392        393     111      37
# 2881818      2.0         2.0      1270.0        99         97      27      23
# 3213513      2.0         2.0      1448.0       212          0      67      42
#
#          year
# 1185711  2018
# 2297401  2017
# 1413780  2014
# 2867187  2017
# 26331    2018
# 2136186  2016
# 764125   2014
# 3223537  2016
# 2216038  2016
# 3734453  2015
# 3065461  2017
# 1238484  2016
# 614025   2018
# 278058   2016
# 456564   2016
# 1338149  2017
# 3776656  2016
# 4233163  2016
# 2765600  2017
# 664312   2014
# 2338837  2016
# 380089   2014
# 1298379  2015
# 3730785  2015
# 3600494  2016
# 4660385  2016
# 2157298  2017
# 976798   2016
# 2462532  2015
# 3772623  2016
# 1187193  2014
# 148186   2018
# 100642   2015
# 4321080  2016
# 59133    2017
# 208569   2014
# 3044403  2015
# 4225207  2016
# 2549919  2015
# 642905   2018
# 3089965  2016
# 1048450  2017
# 503764   2014
# 3902643  2015
# 932674   2015
# 3702839  2015
# 2240919  2014
# 2596342  2017
# 2881818  2015
# 3213513  2016

# %%
all_data=all_data.merge(srm_df,left_on='trade',right_on="id").drop("trade_x",axis=1).rename({"trade_y":"trade"},axis=1)

# %%
all_data_but_2013 =  all_data[all_data.year != 2013].copy()

# %%
all_data_but_2013
for col in ['swipeIn','swipeOut']:
    all_data_but_2013[col] = pd.to_datetime(all_data_but_2013[col])

# %%
test = all_data_but_2013.sample(100).copy()

# %%
all_data_but_2013["work_hours"] = (all_data_but_2013.swipeOut - all_data_but_2013.swipeIn).dt.seconds/3600

# %%
all_data_but_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16778344 entries, 302 to 17169612
# Data columns (total 15 columns):
# userid        uint32
# swipeIn       datetime64[ns]
# swipeOut      datetime64[ns]
# auto          int64
# company       uint16
# company_de    uint16
# panel_in      int64
# panel_out     int64
# AreaID        int64
# SiteID        int64
# year          int64
# active        int64
# id            int64
# trade         object
# work_hours    float64
# dtypes: datetime64[ns](2), float64(1), int64(8), object(1), uint16(2), uint32(1)
# memory usage: 1.8+ GB

# %%
all_data_but_2013.describe()
# Out:
#              userid          auto       company    company_de         trade  \
# count  1.677989e+07  1.678565e+07  1.677985e+07  1.677985e+07  1.677985e+07
# mean   6.015308e+04  9.697624e-02  9.219648e+02  9.173471e+02  1.530770e+03
# std    3.207629e+04  2.959254e-01  9.646943e+02  9.844036e+02  4.776775e+02
# min    2.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.130000e+03
# 25%    3.442600e+04  0.000000e+00  1.510000e+02  1.240000e+02  1.229000e+03
# 50%    6.097500e+04  0.000000e+00  6.700000e+02  6.490000e+02  1.310000e+03
# 75%    8.249800e+04  0.000000e+00  1.354000e+03  1.354000e+03  1.657000e+03
# max    9.999999e+06  1.000000e+00  4.242000e+03  4.242000e+03  3.579000e+03
#
#            panel_in     panel_out        AreaID        SiteID          year  \
# count  1.678565e+07  1.678565e+07  1.678565e+07  1.678565e+07  1.678565e+07
# mean   2.152063e+02  1.923528e+02  5.553842e+01  3.607409e+01  2.015781e+03
# std    1.376989e+02  1.447615e+02  3.556267e+01  2.156408e+01  1.138243e+00
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  2.014000e+03
# 25%    7.400000e+01  7.100000e+01  1.800000e+01  1.500000e+01  2.015000e+03
# 50%    2.100000e+02  1.790000e+02  5.300000e+01  3.700000e+01  2.016000e+03
# 75%    3.230000e+02  3.020000e+02  7.400000e+01  4.200000e+01  2.017000e+03
# max    5.350000e+02  5.360000e+02  1.420000e+02  9.600000e+01  2.018000e+03
#
#          work_hours
# count  1.674712e+07
# mean   1.493751e+00
# std    2.364657e+00
# min    0.000000e+00
# 25%    9.416667e-02
# 50%    5.761111e-01
# 75%    1.930278e+00
# max    2.399861e+01

# %%
all_data_but_2013[all_data_but_2013.work_hours > 23].trade.value_counts()
# Out:
# FIXER                        151
# LABOURER                     142
# ELECTRICIAN                  104
# VISITOR                       98
# CARPENTER                     69
# OPERATIVE                     52
# ENGINEER                      49
# JOINER                        39
# SUPERVISOR                    38
# STEEL ERECTOR                 37
# GROUND WORKER                 36
# SCAFFOLDER                    30
# SECURITY                      29
# BRICKLAYER                    29
# PLUMBER                       28
# ROOFER                        27
# GENERAL OPERATIVE             26
# WELDER                        26
# PIPE FITTER                   25
# PROJECT MANAGER               24
# STEEL FIXER                   23
# SITE MANAGER                  19
# MANAGER                       16
# CONSTRUCTION MANAGER          16
# CLADDER                       16
# FITTER                        15
# CRANE DRIVER                  15
# CONCRETER                     14
# FOREMAN                       14
# PAINTER                       14
#                             ...
# SECRETARY                      1
# MECHANICAL ENGINEER            1
# PILING OPERATIVE               1
# PLANNING MANAGER               1
# REPAIR TECH                    1
# ASSISTANT PROJECT MANAGER      1
# A C ENGINEER                   1
# JOINERY                        1
# NA                             1
# STEEL FIXER LABOURER           1
# ELECTRICIANS MATE              1
# WHITESMITH                     1
# VENT MATE                      1
# PUMP OPERATOR                  1
# LIFT INSTALLER                 1
# PLUMBING SUPERVISOR            1
# WORKS FOREMAN                  1
# DUCTWORK ENGINEER              1
# NURSE                          1
# CONCRETE OPERATOR              1
# EARTHING ENGINEER              1
# ASBESTOS SURVEYOR              1
# PAINT SPRAYER                  1
# FIRE SPRINKLER ENGINEER        1
# FINISHING MANAGER              1
# LOGISTIC MANAGER               1
# RIGGER                         1
# CABLER                         1
# GLAZIER                        1
# PLANNER                        1
# Name: trade, Length: 324, dtype: int64

# %%
all_data_but_2013["swipeIn_date"] =all_data_but_2013.swipeIn.dt.date

# %%
swipe_per_day_per_user = all_data_but_2013.groupby(["userid","swipeIn_date"]).agg({'userid': 'count', 'work_hours': ['sum','max',"median",'min']})

# %%
swip

# %%
all_data_but_2013[all_data_but_2013.userid==130656]
# Out:
#           userid             swipeIn            swipeOut  auto  company  \
# 13674017  130656 2018-09-19 10:50:15 2018-09-19 12:14:21     0     1400
# 13674018  130656 2018-09-19 12:55:07 2018-09-19 14:36:38     0     1400
# 13674019  130656 2018-09-19 14:45:28 2018-09-19 16:24:05     0     1400
# 13674020  130656 2018-09-20 08:08:45                 NaT     0     1400
#
#           company_de  panel_in  panel_out  AreaID  SiteID  year  active    id  \
# 13674017        1400       465        466     110      75  2018       1  1781
# 13674018        1400       465        466     110      75  2018       1  1781
# 13674019        1400       465        466     110      75  2018       1  1781
# 13674020        1400       465          0     110      75  2018       1  1781
#
#          trade  work_hours swipeIn_date
# 13674017   BMS    1.401667   2018-09-19
# 13674018   BMS    1.691944   2018-09-19
# 13674019   BMS    1.643611   2018-09-19
# 13674020   BMS         NaN   2018-09-20

# %%
all_data_but_2013["swipe_in_out_same_day"] = all_data_but_2013.swipeIn.dt.date == all_data_but_2013.swipeOut.dt.date

# %% [markdown]
# # Structure
#
# 5 columns, with missing value mostly in the first column.
# - PMID/PMCID, renamed without special character, old w few missing values and does not seem to be useful for the rest of the study : dropped
# - Publisher: renamed with lowercase
# - Journal title: renamed with lowercase and no space, one missing value but apparently it is a book, to be dropped for the first part of the study...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222295 entries, 0 to 1222294
# Data columns (total 11 columns):
# 0     1221799 non-null float64
# 1     1222295 non-null object
# 2     1216900 non-null object
# 3     1222295 non-null int64
# 4     1221797 non-null float64
# 5     1221797 non-null float64
# 6     1221797 non-null float64
# 7     1222295 non-null int64
# 8     1222295 non-null int64
# 9     1222295 non-null int64
# 10    1222295 non-null int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 102.6+ MB

# %%
data.columns = headers.columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222295 entries, 0 to 1222294
# Data columns (total 11 columns):
# userid        1221799 non-null float64
# swipeIn       1222295 non-null object
# swipeOut      1216900 non-null object
# auto          1222295 non-null int64
# company       1221797 non-null float64
# company_de    1221797 non-null float64
# trade         1221797 non-null float64
# panel_in      1222295 non-null int64
# panel_out     1222295 non-null int64
# AreaID        1222295 non-null int64
# SiteID        1222295 non-null int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 102.6+ MB

# %%
data.sample(10)
# Out:
#            userid                  swipeIn                 swipeOut  auto  \
# 1171258  121585.0  2018-09-04 09:59:43.000  2018-09-04 15:32:04.000     0
# 936854    69670.0  2018-06-14 10:40:03.000  2018-06-14 13:17:10.000     0
# 778481   112630.0  2018-05-04 07:11:18.000  2018-05-04 16:27:40.000     0
# 576147   112096.0  2018-03-28 14:00:51.000  2018-03-28 17:31:07.000     0
# 520997   106918.0  2018-03-21 07:51:05.000  2018-03-21 16:43:32.000     0
# 565754    96629.0  2018-03-27 11:30:22.000  2018-03-27 12:26:39.000     0
# 253812   119221.0  2018-02-12 10:20:19.000  2018-02-12 11:04:24.000     0
# 451476    72582.0  2018-03-12 10:27:53.000  2018-03-12 10:31:34.000     0
# 461431   119217.0  2018-03-13 07:23:25.000  2018-03-13 15:39:33.000     0
# 745440     7077.0  2018-04-27 08:36:30.000  2018-04-27 08:55:06.000     0
#
#          company  company_de   trade  panel_in  panel_out  AreaID  SiteID
# 1171258   4058.0      4058.0  1627.0       435        438     121      86
# 936854     853.0       853.0  1153.0       505        506     138      96
# 778481    1047.0      1047.0  1202.0       376        377     107      74
# 576147     853.0       853.0  1353.0       505        506     138      96
# 520997    1195.0      1195.0  3147.0       358        361     102      71
# 565754    1718.0      1718.0  1202.0       301        302      89      41
# 253812     134.0      3611.0  1153.0       459        456     126      85
# 451476    1825.0      1825.0  2997.0       301        302      89      41
# 461431    3932.0      3932.0  1375.0       437        436     121      86
# 745440       2.0         2.0  1281.0       465        466     110      75

# %%
data = data.drop('PMID_PMCID',axis=1)
data[data.journal.isna()]
# Out:
#      publisher journal                                            article  \
# 986  MacMillan     NaN  Fungal Disease in Britain and the United State...
#
#           cost
# 986  £13200.00

# %%
words = list()
for col in ["publisher","journal"]
data.publisher.str.lower().str.strip().unique()
# Out:
# array(['cup', 'acs', 'acs (amercian chemical society) publications',
#        'acs publications', 'aga institute', 'ambsb',
#        'american association of immunologists',
#        'american chemical society',
#        'american chemical society publications',
#        'american college of chest physicians',
#        'american physiological society',
#        'american psychiatric association',
#        'american psychiatric publishing',
#        'american psychological association',
#        'american public health association',
#        'american soc for biochemistry and molecular biology',
#        'american society for biochemistry and molecular biolgy',
#        'american society for biochemistry and molecular biology',
#        'american society for investigative pathology',
#        'american society for microbiology',
#        'american society for nutrition',
#        'american society of haematology',
#        'american society of hamatology', 'american society of hematology',
#        'american society of human genetics (elsevier)',
#        'american society of microbiology',
#        'american speech-language-hearing association', 'asbmb',
#        'asbmb cadmus', 'asbmb/cadmus', 'asbmb/cenveo publisher services',
#        'asbmc /cenveo', 'asm', 'asm (american society for microbiology)',
#        'association for research in vision & ophthalmology',
#        'bentham science publishers', 'benthan science publishers',
#        'berhahn books', 'biochem journal', 'biomed central',
#        'biomed central limited', 'biomed central ltd',
#        'biophysical society', 'bioscientifica',
#        'blackwell publishing ltd/wiley', 'bmc', 'bmj', 'bmj group',
#        'bmj journals', 'bmj publishing group', 'bmj publishing group ltd',
#        'bmj publishing group ltd & british thoracic society', 'brill',
#        'british medical journal', 'byophysical society', 'cadmus',
#        'cadmus journal service', 'cadmus journal services',
#        'cambridge journals', 'cambridge uni press',
#        'cambridge univ press', 'cambridge university press',
#        'camdus journal services', 'cell press',
#        'cenveo publisher services', 'cenveo publisher services/asm jv1',
#        'coaction', 'cold spring habour press', 'cold spring harbor',
#        'cold spring harbor laboratory press', 'cold spring harbor press',
#        'cold spring harbor publications', 'company of biologist',
#        'company of biologists', 'company of biologists ltd',
#        'copyright clearace center', 'cshlp', 'darmouth journal services',
#        'dartmouth journal services', 'dartmouth journals',
#        'elseveier science', 'elsevier', 'elsevier (cell press)',
#        'elsevier / cell science', 'elsevier b.v.', 'elsevier ltd',
#        'elsevier/cell press', 'endocrine society',
#        'european respiratory society', 'european society of endocrinolog',
#        'faseb',
#        'federation of american societies for experimental biology',
#        'federation of american societies for experimental biology (faseb)',
#        'federation of the american society of experimental biology',
#        'ferrata storti foundation', 'frontiers', 'frontiers media',
#        'frontiers media sa', 'frontiers research foundation',
#        'future medicine', 'future medicine ltd', 'future science',
#        'hindawi', 'hindawi publishing corporation',
#        'humana press (springer imprint)', 'impact journals',
#        'impact journals llc', 'informa healthcare',
#        'informa healthcare communications', 'institute of physics',
#        'international aids society',
#        'international union against tuberculosis and lung disease',
#        'international union of crystallography',
#        'international union of crystallography (iucr)', 'iop publishing',
#        'ios press', 'ivyspring international publisher',
#        'j med internet research', 'john wiley', 'john wiley & sons',
#        'john wiley & sons inc', 'john wiley & sons ltd',
#        'john wiley & sons, inc.', 'john wiley and sons',
#        'john wiley and sons ltd', 'johns hopkins university press',
#        'journal of the american physiological proceedings of national academy of sciences',
#        'journal of visualized experiments', 'jove', 'jscimed central',
#        'karger', 'landes bioscience', 'landes biosciences', 'lww',
#        'macmillan', 'mary ann liebert', 'mary ann liebert inc',
#        'mary ann liebert, inc. publishers', 'mdpi', 'mit press',
#        'mit press open access', 'my jove corp', 'my jove corporation',
#        'myjove corporation', 'national academy of sciences',
#        'national academy of sciences of the united states of america',
#        'national academy of sciences usa',
#        'national academy of sciences, usa', 'nature', 'nature pg',
#        'nature publishing', 'nature publishing group',
#        'nature publishing group ltd', 'npg', 'open access reg ltd',
#        'optical society of america', 'oup', 'oxford journals',
#        'oxford journals (oup)', 'oxford univ press',
#        'oxford university press', 'oxford university press (oup)',
#        'oxford univesity press', 'palgrave macmillan', 'pion', 'plos',
#        'plos (public library of science)',
#        'plos public library of science', 'pnas',
#        'pnas author publication', 'policy press', 'portland press',
#        'portland press ltd',
#        'proceedings of the national academy of sciences (pnas)',
#        'public library of science', 'public.service.co.uk',
#        'publisher society for endocrinology', 'pubmed', 'pubmed central',
#        'research media ltd', 'royal college of psychiatrists',
#        'royal society', 'royal society for chemistry',
#        'royal society of chemistry', 'rsc', 'rsc publishing', 'sage',
#        'sage publications', 'sage publications inc',
#        'sage publications ltd', 'sage publishers', 'sage publishing',
#        'sciedu press', 'scientific research publishing', 'sheridan press',
#        'society for endocrinology', 'society for general microbiology',
#        'society for genermal microbiology',
#        'society for leukocyte biology', 'society for neuroscience',
#        'society for neurosciences',
#        'society for publication of acta dermato-venereologica',
#        'society of general microbiology', 'society of leukocyte biology',
#        'society of neuro sciences', 'society of neuroscience', 'springer',
#        'springer - verlag gmbh', 'springer science + business media',
#        'springer verlag', 'springer-veriag gmbh', 'springer-verlag gmbh',
#        'springer-verlag gmbh & ci',
#        'springer-verlag gmbh, heidelberger platz 3, d-14197 berlin',
#        't&f', 'taylor & francis', 'taylor & francis journals',
#        'taylor and francis',
#        'the american chemical society petroleum research trust',
#        'the american physiological society',
#        'the american society for biochemistry and molecular biology',
#        'the american society for biochemistry and molecular biology, inc',
#        'the american society of pediatrics', 'the boulevard',
#        'the company of biolgists', 'the company of biologists',
#        'the company of biologists ltd', 'the endocrine socety',
#        'the endocrine society', 'the endrocrine society',
#        'the journal of visualized experiments',
#        'the royal college of psychiatrists', 'the royal society',
#        'the sheridan press', 'transcript verlag',
#        'university of the basque country press', 'wiley', 'wiley & son',
#        'wiley blackwell', 'wiley online library',
#        'wiley subscription services', 'wiley subscription services  inc.',
#        'wiley subscription services inc',
#        'wiley subscription serviices inc', 'wiley vch', 'wiley/blackwell',
#        'wiley-blackwell', 'wiley-blackwell, john wiley & sons',
#        'wiley-vch', 'wliey-blackwell', 'wolters kluwer',
#        'wolters kluwer health', 'wolters kluwer n.v./lippinott',
#        'wolters kluwers'], dtype=object)

# %% [markdown]
# <a id="part_one"></a>
# # Part one : which journal are the most used
#
# All journal name and article, lowercase, stripped of white space.
# Then went through iterative process to:
# - Remove common words (list `words_to_remove`)
# - Correcting typos (dictionnay `words_to_change`)
# - Changing the complete title (dictionnay `title_to_change`)
#
# Also removing double spaces.
#
# To check for further changes, used a test on top 15 answers and looked for other potential similar journal title using `editdistence` (aka Levenshtein distance)
#
# At the end only 2 duplicate line removed.
#
# Final results:
# - PLoS One	: 213
# - Journal of Biological Chemistry	: 71
# - Proceedings of the National Academy of Sciences :	36
# - Neuroimage :	31
# - Nucleic Acids Research :	29

# %%
test = data[["journal","article"]].copy()
print(test.shape)
test = test.dropna()
print(test.shape)

words_to_remove = ["the",r"^the","of","and","&","in",',',':']
words_to_change = {
    "the journal": "journal",
    "journals": "journal",
    "j": "journal",
    "bio": 'biological',
    "biol": 'biological',
    "biologicial": "biological",
    "plosone": "plos one",
    "jounral": "journal",
    "jnl": "journal",
    "dev": "developing",
    "am": "american",
    "int": "international",
    "ntd": "neglected tropical diseases",
    "neurolmage": "neuroimage",
    "negected": "neglected",
    "biochem": "biochemical",
    "journal s": "journal",
    "proceddings":"proceedings",
    "neurosciences":"neuroscience",
    "med chem": "medicinal chemistry"
}
title_to_change = {
    "proceddings national academy sciences usa":'proceedings national academy sciences',
    "pnas":'proceedings national academy sciences',
    'pnas ( proceedings national academy sciences united states america':'proceedings national academy sciences',
    'pnas usa':'proceedings national academy sciences',
    'national academy sciences' : 'proceedings national academy sciences',
    "journal biological chem":'journal biological chemistry',
    "journal biological chem":"journal biological chemistry",
    'neglected tropical disease': 'plos neglected tropical diseases',
    'proceedings national academy sciences (pnas)': 'proceedings national academy sciences',
    "plos 1": "plos one",
    "plos": "plos one",
    "public library science one": "plos one",
    "nucleic acid research": "nucleic acids research",
    'proceedings national academy sciences usa': 'proceedings national academy sciences',
    "the biochemical journal":"biochemical journal",
    "human molecular genetics online":"human molecular genetics",
    "aids": "journal aids",
    "journal aids": "journal acquired immune deficiency syndromes",
    "pone-d12-17947": "plos one",
    "public library science": "plos one"
}
for col in test.columns:
    test[col] = test[col].str.lower().str.replace("."," ").str.strip()
    for word in words_to_remove:
        test[col] = test[col].str.replace(r"\W"+word+"\W"," ").str.strip()
    test[col] = test[col].str.replace("  "," ").str.strip()
    test = test.dropna()

col = "journal"
test[col] = " "+test[col]+" "
for old,new in words_to_change.items():
    test[col] = test[col].str.replace(r"\W("+old+")\W"," "+new+" ")
    test[col] = test[col].str.replace(new," "+new+" ")
    test[col] = test[col].str.replace("  "," ")
test[col] = test[col].str.strip()
for old,new in title_to_change.items():
    test[col][test[col]==old] = new

test[col] = test[col].str.replace("  "," ")
test[col] = test[col].str.strip()
# Out:
# (2127, 2)
# (2126, 2)

# %%
#Any duplicate to remove?
print(test.shape)
test = test.drop_duplicates()
print(test.shape)
# Out:
# (2126, 2)
# (2124, 2)

# %%
best = test.journal.value_counts()
best = best.sort_values(ascending=False)

# %%
#for the top 15 check if there is another title at a edit distance of less than 8 or the len divded by 2
for ref in best[:15].index:
    this_one = test.journal.apply(lambda x: editdistance.eval(ref, x))
    criteria = min([15,len(ref)//2])
    other_ones = test[this_one < criteria].journal.unique()
    if len(other_ones)>1:
        print(ref)
        for other_one in sorted(other_ones):
            if other_one != ref:
                print(other_one)
        print("===================>")
# Out:
# journal biological chemistry
# analytical chemistry
# biological chemistry
# current analytical chemistry
# future medicinal chemistry
# journal bioethical inquiry
# journal biological physics
# journal cellular biochemistry
# journal clinical epidemiology
# journal clinical pathology
# journal clinical virology
# journal historical geography
# journal medicinal chemistry
# journal neurochemistry
# journal neurological sciences
# journal org chem
# journal public health
# journal virological methods
# organic biomolecular chemistry
# ===================>
# neuroimage
# neurology
# ===================>
# nucleic acids research
# cell tissue research
# circulation research
# inflammation research
# qualitative research
# stem cell research
# ===================>
# plos genetics
# bmc genetics
# bms genomics
# epigenetics
# genetics
# neurogenetics
# trends genetics
# ===================>
# human molecular genetics
# annals human genetics
# bmc medical genetics
# embo molecular medicine
# journal medical genetics
# journal molecular medicine
# ===================>
# nature communications
# chemical communication
# ===================>
# biochemical journal
# biochemical soc trans
# biophysical journal
# british medical journal
# cell journal
# ===================>
# journal neuroscience
# behavioral neuroscience
# bmc neuroscience
# european journal neuroscience
# journal cell sci
# journal cell science
# journal microscopy
# journal neurochemistry
# journal neurological sciences
# journal neurology
# journal neurophysiology
# journal neuroscience methods
# journal nutrition
# journal org chem
# journal proteomics
# journal vision
# nature neuroscience
# neuroscience
# trends neuroscience
# visual neuroscience
# ===================>
# bmc public health
# journal public health
# public health
# ===================>

# %%
best[:5].plot(kind="bar")

# %%
best[:5]
# Out:
# plos one                                 213
# journal biological chemistry              71
# proceedings national academy sciences     36
# neuroimage                                31
# nucleic acids research                    29
# Name: journal, dtype: int64

# %%
for_data = data.join(test, rsuffix='_new',how='inner')

# %%
for_data.sample(10)
# Out:
#                                               publisher  \
# 1042                                             Nature
# 1831  The American Chemical Society Petroleum Resear...
# 858                                               FASEB
# 876                                           Frontiers
# 1975                                              Wiley
# 1779                                           Springer
# 1065                            Nature Publishing Group
# 699                                            Elsevier
# 1511                          Public Library of Science
# 598                                            Elsevier
#
#                                     journal  \
# 1042                  Nature Communications
# 1831                            J Med Chem.
# 858                       The FASEB Journal
# 876   Frontiers in Developmental Psychology
# 1975                     Movement Disorders
# 1779                        Pflugers Archiv
# 1065                           EMBO Reports
# 699                              NeuroImage
# 1511                               PLOS ONE
# 598   International Journal of Parasitology
#
#                                                 article        cost  \
# 1042  A role for piezo2 in EPAC1 dependent mechanic...    £2562.00
# 1831  7,8-dichloro-1-oxo-?-carbolines as a versatile...    £1535.56
# 858   Asprin-triggered 15-epi lipoxin A4 predicts cy...     £824.16
# 876   Severity of specific language impairment predi...     £840.19
# 1975  Somatic alpha-synuclein mutations in Parkinson...    £1005.00
# 1779  Kv1 and Kir2 potassium channels are expressed ...    £1955.03
# 1065  Physiological release of endogenous tau is sti...  £999999.00
# 699   5-HTTLPR  environment interplay and its effec...    £2280.14
# 1511  Alterations to dendritic spine morphology, but...     £850.50
# 598   Proteome analysis of the Theileria annulata sc...    £2386.44
#
#                              journal_new  \
# 1042               nature communications
# 1831         journal medicinal chemistry
# 858                    the faseb journal
# 876   frontiers developmental psychology
# 1975                  movement disorders
# 1779                     pflugers archiv
# 1065                        embo reports
# 699                           neuroimage
# 1511                            plos one
# 598   international journal parasitology
#
#                                             article_new
# 1042  a role for piezo2 epac1 dependent mechanical ...
# 1831  7,8-dichloro-1-oxo-?-carbolines as a versatile...
# 858   asprin-triggered 15-epi lipoxin a4 predicts cy...
# 876   severity specific language impairment predicts...
# 1975  somatic alpha-synuclein mutations parkinson&ap...
# 1779  kv1 kir2 potassium channels are expressed rat ...
# 1065  physiological release endogenous tau is stimul...
# 699   5-httlpr  environment interplay its effects o...
# 1511  alterations to dendritic spine morphology, but...
# 598       proteome analysis theileria annulata schizont

# %%
fromnew_to_old = for_data.groupby(['journal_new','journal']).agg({'article_new': 'count', 'journal': 'count'})\
.sort_values("article_new",ascending=False)\
.rename(columns={'journal':'journal_count'})\
.reset_index()\
.drop_duplicates(subset=["journal_new"])\
.drop(["article_new","journal_count"],axis=1)

# %%
best.to_frame().reset_index().rename(columns={'journal':'journal_count'})\
.merge(fromnew_to_old,left_on='index',right_on="journal_new")\
.drop("index",axis=1).loc[:4][["journal","journal_count"]]
# Out:
#                                            journal  journal_count
# 0                                         PLoS One            208
# 1                  Journal of Biological Chemistry             71
# 2  Proceedings of the National Academy of Sciences             36
# 3                                       Neuroimage             31
# 4                           Nucleic Acids Research             29

# %%
for_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2124 entries, 0 to 2126
# Data columns (total 6 columns):
# publisher      2124 non-null object
# journal        2124 non-null object
# article        2124 non-null object
# cost           2124 non-null object
# journal_new    2124 non-null object
# article_new    2124 non-null object
# dtypes: object(6)
# memory usage: 116.2+ KB

# %%
for_data[:10].cost
# Out:
# 0       £0.00
# 1    £2381.04
# 2     £642.56
# 3     £669.64
# 4     £685.88
# 5    £2392.20
# 6    £2367.95
# 7     £649.33
# 8    £1294.59
# 9    £1294.78
# Name: cost, dtype: object

# %%
for_data["currency"] = for_data.cost.str.extract(r'([\$|\£])',expand=False)
for_data["value"] = for_data.cost.str.replace(r'([\$|\£])',"")
for_data["value"] = pd.to_numeric(for_data.value)

# %%
for_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2124 entries, 0 to 2126
# Data columns (total 8 columns):
# publisher      2124 non-null object
# journal        2124 non-null object
# article        2124 non-null object
# cost           2124 non-null object
# journal_new    2124 non-null object
# article_new    2124 non-null object
# currency       2124 non-null object
# value          2124 non-null float64
# dtypes: float64(1), object(7)
# memory usage: 149.3+ KB

# %%
#Looking at the distribution there seems to be a few outliars
g = sns.boxplot(data=for_data,y="value")
g.semilogy()
g.set_title("Distribution of the value (in GBP) for each article to outline outliar values.");

# %%
for_data.sort_values("value",ascending=False)[:5]
# Out:
#                       publisher  \
# 1566  Public Library of Science
# 410                         CUP
# 1561  Public Library of Science
# 1562  Public Library of Science
# 1563  Public Library of Science
#
#                                              journal  \
# 1566                                        PLoS ONE
# 410   Journal of the International African Institute
# 1561                                        PLOS ONE
# 1562                                        PLoS One
# 1563                                        PLoS ONE
#
#                                                 article        cost  \
# 1566  Phenotypic alteration of neutrophils in the bl...  £999999.00
# 410         Pharmacy, money and public health in Dakar.  £999999.00
# 1561  Pharmacological inhibition of caspase-2 protec...  £999999.00
# 1562  Population-based CD4 counts in a rural area in...  £999999.00
# 1563  Plant SILAC: stable-isotope labelling with ami...  £999999.00
#
#                                   journal_new  \
# 1566                                 plos one
# 410   journal international african institute
# 1561                                 plos one
# 1562                                 plos one
# 1563                                 plos one
#
#                                             article_new currency     value
# 1566  phenotypic alteration neutrophils blood hiv se...        £  999999.0
# 410                 pharmacy, money public health dakar        £  999999.0
# 1561  pharmacological inhibition caspase-2 protects ...        £  999999.0
# 1562  population-based cd4 counts a rural area south...        £  999999.0
# 1563  plant silac: stable-isotope labelling with ami...        £  999999.0

# %%
for_data.value = for_data.value.replace(999999.0,np.nan)

# %%
for_data.sort_values("value",ascending=False)[:5]
# Out:
#                       publisher                journal  \
# 1987                      Wiley     Movement Disorders
# 1470  Public Library of Science               PLoS One
# 1619       public.service.co.uk  Public Service Review
# 800                    Elsevier   The Lancet Neurology
# 648                    Elsevier                 Lancet
#
#                                                 article        cost  \
# 1987  Limb amputations in fixed dystonia: a form of ...  £201024.00
# 1470  Reducing stock-outs of life saving Malaria Com...  £192645.00
# 1619            Laboratory Science in Tropical Medicine    £6000.00
# 800   Genetic risk factors for ischaemic stroke and ...    £5760.00
# 648   Global trends in antiretroviral resistance in ...    £4800.00
#
#                 journal_new  \
# 1987     movement disorders
# 1470               plos one
# 1619  public service review
# 800    the lancet neurology
# 648                  lancet
#
#                                             article_new currency     value
# 1987  limb amputations fixed dystonia: a form body i...        £  201024.0
# 1470  reducing stock-outs life saving malaria commod...        £  192645.0
# 1619               laboratory science tropical medicine        £    6000.0
# 800   genetic risk factors for ischaemic stroke its ...        £    5760.0
# 648   global trends antiretroviral resistance treatm...        £    4800.0

# %%
#This looks like the comma was not positionned correctly
for_data.loc[for_data.index==1470,"value"] = 1926.45

for_data.loc[for_data.index==1987,"value"] = 2010.24

# %%
for_data.sort_values("value",ascending=True)[:5]
# Out:
#                            publisher  \
# 0                                CUP
# 243               BioMed Central Ltd
# 100   American Society for Nutrition
# 1469       Public Library of Science
# 1677                    Sciedu Press
#
#                                            journal  \
# 0                           Psychological Medicine
# 243                            Veterinary Research
# 100                 American Society for Nutrition
# 1469                                      PLoS One
# 1677  Journal of Biomedical Graphics and Computing
#
#                                                 article     cost  \
# 0     Reduced parahippocampal cortical thickness in ...    £0.00
# 243   Understanding foot-and-mouth disease virus tra...    £9.93
# 100   The association between breastfeeding and HIV ...   £45.94
# 1469  How  well are Malaria Maps used to design and ...  £122.31
# 1677  Functional MRI demonstrates pain perception in...  £135.29
#
#                                 journal_new  \
# 0                    psychological medicine
# 243                     veterinary research
# 100          american society for nutrition
# 1469                               plos one
# 1677  journal biomedical graphics computing
#
#                                             article_new currency   value
# 0     reduced parahippocampal cortical thickness sub...        £    0.00
# 243   understanding foot mouth disease virus transmi...        £    9.93
# 100   the association between breastfeeding hiv on p...        £   45.94
# 1469  how well are malaria maps used to design finan...        £  122.31
# 1677  functional mri demonstrates pain perception ha...        £  135.29

# %%
for_data["value"] = for_data["value"].fillna(for_data.groupby("journal_new")["value"].transform("median"))

# %%
for_data[for_data.publisher.str.contains("public.*library",case=False)].journal_new.unique()
# Out:
# array(['plos genetics', 'plos one', 'biology', 'computational biology',
#        'plos neglected tropical diseases', 'plos computational biology',
#        'plos biology', 'plos medicine', 'plos medicine journal',
#        'plos pathogens', 'pmedicine-d-12-03130', 'pntd',
#        'public library science'], dtype=object)

# %%
for_data["value"] = for_data["value"].fillna(np.median(for_data[~for_data.value.isna()].value))

# %%
for_data.sort_values("value",ascending=False)[:10]
# Out:
#                  publisher                journal  \
# 1619  public.service.co.uk  Public Service Review
# 800               Elsevier   The Lancet Neurology
# 552               Elsevier               Elsevier
# 798               Elsevier             The Lancet
# 648               Elsevier                 Lancet
# 797               Elsevier             The Lancet
# 799               Elsevier   The Lancet Neurology
# 796               Elsevier             The Lancet
# 844    Elsevier/Cell Press    Cell Host & Microbe
# 729               Elsevier                 Neuron
#
#                                                 article      cost  \
# 1619            Laboratory Science in Tropical Medicine  £6000.00
# 800   Genetic risk factors for ischaemic stroke and ...  £5760.00
# 552   Effects of relative weight gain and linear gro...  £4800.00
# 798   Effects of unconditional and conditional cash ...  £4800.00
# 648   Global trends in antiretroviral resistance in ...  £4800.00
# 797   The impact on a serogroup a meningococcal conj...  £4554.01
# 799   MRI investigation of the sensorimotor cortex a...  £4320.00
# 796   Dementia incidence and mortality in middle inc...  £4320.00
# 844   Human cytomegalovirus UL141 targets the TRAIL ...  £4226.04
# 729   Distinct contributions of rod, cone, and melan...  £4170.35
#
#                 journal_new  \
# 1619  public service review
# 800    the lancet neurology
# 552                elsevier
# 798              the lancet
# 648                  lancet
# 797              the lancet
# 799    the lancet neurology
# 796              the lancet
# 844       cell host microbe
# 729                  neuron
#
#                                             article_new currency    value
# 1619               laboratory science tropical medicine        £  6000.00
# 800   genetic risk factors for ischaemic stroke its ...        £  5760.00
# 552   effects relative weight gain linear growth dur...        £  4800.00
# 798   effects unconditional conditional cash transfe...        £  4800.00
# 648   global trends antiretroviral resistance treatm...        £  4800.00
# 797   the impact on a serogroup a meningococcal conj...        £  4554.01
# 799   mri investigation sensorimotor cortex corticos...        £  4320.00
# 796   dementia incidence mortality middle income cou...        £  4320.00
# 844   human cytomegalovirus ul141 targets trail deat...        £  4226.04
# 729   distinct contributions rod, cone, melanopsin p...        £  4170.35

# %%
group_information = for_data.groupby('journal_new').agg({'article_new': 'count', 'value': ['sum','max',"median",'min']}).sort_values(("article_new","count"),ascending=False)

# %%
group_information
# Out:
#                                           article_new       value           \
#                                                 count         sum      max
# journal_new
# plos one                                          206  193403.950  1926.45
# journal biological chemistry                       71   98248.890  2501.07
# proceedings national academy sciences              36   30716.170  2691.68
# neuroimage                                         31   68577.620  2518.23
# nucleic acids research                             29   33708.000  2184.00
# plos genetics                                      24   39573.900  1809.51
# plos pathogens                                     24   37803.570  1784.65
# plos neglected tropical diseases                   24   41325.010  3600.00
# human molecular genetics                           20   40478.750  2100.00
# nature communications                              19   60056.400  3780.00
# biochemical journal                                16   30250.000  2100.00
# movement disorders                                 15   28638.060  2395.87
# journal neuroscience                               15   28209.480  2950.25
# bmc public health                                  15   19021.220  1608.00
# brain                                              14   30320.000  2400.00
# journal medicinal chemistry                        13   13682.380  2392.20
# developmental cell                                 12   39507.260  4099.71
# journal general virology                           11   21875.000  2100.00
# current biology                                    11   38628.510  4112.54
# plos computational biology                         10   15311.120  1783.84
# bmj                                                10   27510.000  3600.00
# malaria journal                                    10   13224.600  1632.00
# journal virology                                    9   14644.420  2019.89
# cell reports                                        9   32798.040  3995.74
# bmj open                                            9   14119.800  1680.00
# neuron                                              9   32090.800  4170.35
# journal physiology                                  9   18156.275  2400.00
# development                                         9   17124.000  2400.00
# european journal immunology                         8   17079.470  2380.96
# journal clinical endocrinology metabolism           8   17432.730  2355.52
# ...                                               ...         ...      ...
# heart circulatory physiology                        1    1349.180  1349.18
# genetic epidemology                                 1    1911.300  1911.30
# heptology                                           1    1852.010  1852.01
# hernia                                              1    1897.210  1897.21
# history workshop journal                            1    2100.000  2100.00
# hpb                                                 1    2311.560  2311.56
# hum resour health                                   1    1525.000  1525.00
# human brain mapping                                 1    1500.000  1500.00
# human mol genetics online                           1    2040.000  2040.00
# haematologica                                       1    1567.940  1567.94
# genesis: journal genetics                           1    2376.400  2376.40
# frontiers genetics                                  1     346.250   346.25
# frontiers neurorobotics                             1     625.200   625.20
# frontiers immunological memory                      1     775.820   775.82
# frontiers immunology                                1    1014.440  1014.44
# frontiers inflammation                              1     687.790   687.79
# frontiers integrative neuroscience                  1     937.340   937.34
# frontiers invertebrate physiology                   1     967.180   967.18
# frontiers molecular neuroscience                    1    1209.600  1209.60
# frontiers neural circuits                           1     819.450   819.45
# frontiers perception science                        1     987.910   987.91
# g3: genes, genomes, genetics                        1    1230.670  1230.67
# frontiers schizophrenia                             1     821.980   821.98
# frontiers systems neuroscience                      1    1644.250  1644.25
# frontiers t cell biology                            1    1017.580  1017.58
# fungal biology                                      1    2272.010  2272.01
# fungal ecology                                      1    2378.190  2378.19
# future microbiology                                 1    1700.000  1700.00
# future neurology                                    1    2040.000  2040.00
# zoonoses public health                              1    2272.150  2272.15
#
#
#                                              median      min
# journal_new
# plos one                                    897.090   122.31
# journal biological chemistry               1314.530   265.67
# proceedings national academy sciences       751.840   206.32
# neuroimage                                 2326.430  1747.16
# nucleic acids research                      852.000   710.00
# plos genetics                              1712.730  1394.05
# plos pathogens                             1600.250  1254.02
# plos neglected tropical diseases           1543.150  1283.76
# human molecular genetics                   2040.000  1700.00
# nature communications                      3642.000   910.80
# biochemical journal                        1800.000  1800.00
# movement disorders                         2010.240  1005.00
# journal neuroscience                       2029.470   614.73
# bmc public health                          1315.800   437.00
# brain                                      2040.000  2000.00
# journal medicinal chemistry                1006.720   321.12
# developmental cell                         3861.420   364.17
# journal general virology                   2100.000  1575.00
# current biology                            3857.160   348.33
# plos computational biology                 1476.430  1417.50
# bmj                                        3000.000   810.00
# malaria journal                            1268.700  1113.50
# journal virology                           1577.910  1247.41
# cell reports                               3836.320  3100.01
# bmj open                                   1620.000  1275.00
# neuron                                     3918.420   623.43
# journal physiology                         2018.685  1314.58
# development                                1620.000  1044.00
# european journal immunology                2262.825  1635.00
# journal clinical endocrinology metabolism  2267.675  1909.00
# ...                                             ...      ...
# heart circulatory physiology               1349.180  1349.18
# genetic epidemology                        1911.300  1911.30
# heptology                                  1852.010  1852.01
# hernia                                     1897.210  1897.21
# history workshop journal                   2100.000  2100.00
# hpb                                        2311.560  2311.56
# hum resour health                          1525.000  1525.00
# human brain mapping                        1500.000  1500.00
# human mol genetics online                  2040.000  2040.00
# haematologica                              1567.940  1567.94
# genesis: journal genetics                  2376.400  2376.40
# frontiers genetics                          346.250   346.25
# frontiers neurorobotics                     625.200   625.20
# frontiers immunological memory              775.820   775.82
# frontiers immunology                       1014.440  1014.44
# frontiers inflammation                      687.790   687.79
# frontiers integrative neuroscience          937.340   937.34
# frontiers invertebrate physiology           967.180   967.18
# frontiers molecular neuroscience           1209.600  1209.60
# frontiers neural circuits                   819.450   819.45
# frontiers perception science                987.910   987.91
# g3: genes, genomes, genetics               1230.670  1230.67
# frontiers schizophrenia                     821.980   821.98
# frontiers systems neuroscience             1644.250  1644.25
# frontiers t cell biology                   1017.580  1017.58
# fungal biology                             2272.010  2272.01
# fungal ecology                             2378.190  2378.19
# future microbiology                        1700.000  1700.00
# future neurology                           2040.000  2040.00
# zoonoses public health                     2272.150  2272.15
#
# [830 rows x 5 columns]

# %%
for_data.describe()
# Out:
#              value
# count  2124.000000
# mean   1822.767027
# std     768.242081
# min       0.000000
# 25%    1268.700000
# 50%    1850.575000
# 75%    2298.792500
# max    6000.000000

# %%
for_data.value.sum()
# Out:
# 3871557.165
